# %% [markdown]
# <a href="https://colab.research.google.com/github/suuu004/Weartherist/blob/main/Weatherist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 코랩 셀에서 실행하여 파일 생성
# %%writefile colab_server.py
from fastapi import FastAPI
from pydantic import BaseModel
from google import genai
from google.genai import types
import requests
import base64
import os

app = FastAPI()

class InferenceRequest(BaseModel):
    weather_str: str
    user_input: str

@app.post("/generate-coordination")
def generate_coordination(req: InferenceRequest):
    # 1. Gemini로 코디 텍스트 및 FLUX 프롬프트 생성
    client = genai.Client(api_key="YOUR_GEMINI_KEY")
    prompt = f"날씨: {req.weather_str}\n요청: {req.user_input}\n..." # 이전 프롬프트 활용

    # (중략 - Gemini JSON 출력 로직 수행)
    # result = {'korean_reason': '...', 'image_prompt': '...'}

    # 2. FLUX로 이미지 생성 (Hugging Face API)
    # hf_response = requests.post(...)

    # 3. 이미지를 React/FastAPI가 받기 쉽도록 Base64 바이너리 텍스트로 인코딩
    # encoded_img = base64.b64encode(hf_response.content).decode('utf-8')

    return {
        "korean_reason": "추천 사유 텍스트",
        "image_base64": "encoded_img_string"
    }
# Out:
# Writing colab_server.py

# %%
# 코랩 셀에서 실행
# !pip install uvicorn fastapi google-genai requests
# !uvicorn colab_server:app --host 0.0.0.0 --port 8000 & npx localtunnel --port 8000
# Out:
# ...
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y) INFO:     Started server process [4066]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [4066]
# ^C
